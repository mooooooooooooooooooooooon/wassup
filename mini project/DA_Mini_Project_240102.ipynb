# %% [markdown]
# # DA Mini Project
# * 주제 : 온라인 학습 플랫폼 사용자 행동 패턴 분석
# * 개요 :
# ```
# 이번 프로젝트는 학습 서비스를 이용하는 독자들 중 누가 서비스 구독을 연장할지 예측하기 위한 사전 파악에 초점을 맞추고 있습니다. 우리의 목표는 유저들의 학습 습관, 선호도, 이용 행태 등 다양한 측면을 면밀히 분석하는 것입니다.
#
#
# 이를 위해, 우리는 유저들의 학습 패턴, 서비스 이용 시간, 콘텐츠에 대한 반응, 그리고 이들이 얼마나 자주 서비스를 이용하는지 등 다양한 데이터를 수집하고 분석할 계획입니다. 이 데이터는 유저들이 서비스에 얼마나 만족하고 있는지, 어떤 요소들이 그들의 구독 결정에 영향을 미치는지 이해하는 데 중요한 역할을 할 것입니다.
# ```
# * 데이터셋 : mini.csv
#     * 메타데이터
#         * user_id: 사용자의 고유 식별자
#         * subscription_duration: 사용자가 서비스에 가입한 기간 (월)
#         * recent_login_time: 사용자가 마지막으로 로그인한 시간 (일)
#         * average_login_time:  사용자의 일반적인 로그인 시간
#         * average_time_per_learning_session: 각 학습 세션에 소요된 평균 시간 (분)
#         * monthly_active_learning_days: 월간 활동적인 학습 일수
#         * total_completed_courses: 완료한 총 코스 수
#         * recent_learning_achievement: 최근 학습 성취도
#         * abandoned_learning_sessions: 중단된 학습 세션 수
#         * community_engagement_level: 커뮤니티 참여도
#         * preferred_difficulty_level: 선호하는 난이도
#         * subscription_type: 구독 유형
#         * customer_inquiry_history: 고객 문의 이력
#         * payment_pattern : 사용자의 지난 3개월 간의 결제 패턴을 10진수로 표현한 값.
#           - 7: 3개월 모두 결제함
#           - 6: 첫 2개월은 결제했으나 마지막 달에는 결제하지 않음
#           - 5: 첫 달과 마지막 달에 결제함
#           - 4: 첫 달에만 결제함
#           - 3: 마지막 2개월에 결제함
#           - 2: 가운데 달에만 결제함
#           - 1: 마지막 달에만 결제함
#           - 0: 3개월 동안 결제하지 않음
#         * target: 사용자가 다음 달에도 구독을 계속할지 (1) 또는 취소할지 (0)를 나타냄

# %% [markdown]
# # 데이터를 확인하고 전처리해보자

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import koreanize_matplotlib
import seaborn as sns

df = pd.read_csv('C:\workspace\python\wassup\data\data\데이터분석\mini.csv')
df
# Out:
#        user_id  subscription_duration  recent_login_time  average_login_time  \
# 0     b919c29d                     13                 14           14.946163
# 1     a0a60abb                     16                 18           18.453224
# 2     b9f171ae                     22                  1           16.195228
# 3     5dc0ba8b                      1                 19           17.628656
# 4     65c83654                      4                  5           21.390656
# ...        ...                    ...                ...                 ...
# 9995  ae6b76bc                     22                 29           14.727623
# 9996  24588752                     10                 11           19.374054
# 9997  e4622a54                      7                 27           18.240978
# 9998  e07fbad9                     11                  7           18.783800
# 9999  e12dcb55                     10                  5           13.073230
#
#       average_time_per_learning_session  monthly_active_learning_days  \
# 0                              8.427187                            18
# 1                             72.646087                            16
# 2                             21.774492                            13
# 3                             42.659066                            19
# 4                             30.744287                            19
# ...                                 ...                           ...
# 9995                          84.053558                            18
# 9996                          45.464833                             9
# 9997                         127.302411                            24
# 9998                           5.297234                            10
# 9999                          28.120031                             3
#
#       total_completed_courses  recent_learning_achievement  \
# 0                          16                    68.360455
# 1                          13                    97.567322
# 2                          14                    94.358763
# 3                          18                    70.153228
# 4                          10                    81.917908
# ...                       ...                          ...
# 9995                       16                    64.966803
# 9996                        8                    82.750244
# 9997                       14                    81.567839
# 9998                       10                    89.885656
# 9999                       13                    64.811297
#
#       abandoned_learning_sessions  community_engagement_level  \
# 0                               3                           4
# 1                               2                           3
# 2                               3                           4
# 3                               0                           3
# 4                               2                           4
# ...                           ...                         ...
# 9995                            2                           5
# 9996                            3                           3
# 9997                            3                           5
# 9998                            4                           5
# 9999                            4                           5
#
#      preferred_difficulty_level subscription_type  customer_inquiry_history  \
# 0                           Low             Basic                         4
# 1                        Medium             Basic                         1
# 2                        Medium           Premium                         0
# 3                           Low             Basic                         1
# 4                        Medium             Basic                         3
# ...                         ...               ...                       ...
# 9995                        Low           Premium                         1
# 9996                     Medium             Basic                         2
# 9997                       High             Basic                         1
# 9998                        Low             Basic                         2
# 9999                        Low           Premium                         0
#
#       payment_pattern  target
# 0                   5       0
# 1                   6       1
# 2                   7       1
# 3                   0       1
# 4                   0       1
# ...               ...     ...
# 9995                1       1
# 9996                7       1
# 9997                6       1
# 9998                0       1
# 9999                3       0
#
# [10000 rows x 15 columns]

# %%
# df.columns?

# %% [markdown]
# 칼럼명이 영어니깐 보기도 어렵고 너무 길다. 한글로 바꿔주자

# %%
columns = ['아이디', '가입기간(월)', '최종로그인(일)', '평균접속시간', '학습평균시간(분)', '월간학습일', '완료코스', '학습성취도', '중단학습수', '커뮤참여도', '선호난도', '구독유형', '문의이력', '결제패턴', '연장여부']

df.columns = columns
df
# Out:
#            아이디  가입기간(월)  최종로그인(일)     평균접속시간   학습평균시간(분)  월간학습일  완료코스  \
# 0     b919c29d       13        14  14.946163    8.427187     18    16
# 1     a0a60abb       16        18  18.453224   72.646087     16    13
# 2     b9f171ae       22         1  16.195228   21.774492     13    14
# 3     5dc0ba8b        1        19  17.628656   42.659066     19    18
# 4     65c83654        4         5  21.390656   30.744287     19    10
# ...        ...      ...       ...        ...         ...    ...   ...
# 9995  ae6b76bc       22        29  14.727623   84.053558     18    16
# 9996  24588752       10        11  19.374054   45.464833      9     8
# 9997  e4622a54        7        27  18.240978  127.302411     24    14
# 9998  e07fbad9       11         7  18.783800    5.297234     10    10
# 9999  e12dcb55       10         5  13.073230   28.120031      3    13
#
#           학습성취도  중단학습수  커뮤참여도    선호난도     구독유형  문의이력  결제패턴  연장여부
# 0     68.360455      3      4     Low    Basic     4     5     0
# 1     97.567322      2      3  Medium    Basic     1     6     1
# 2     94.358763      3      4  Medium  Premium     0     7     1
# 3     70.153228      0      3     Low    Basic     1     0     1
# 4     81.917908      2      4  Medium    Basic     3     0     1
# ...         ...    ...    ...     ...      ...   ...   ...   ...
# 9995  64.966803      2      5     Low  Premium     1     1     1
# 9996  82.750244      3      3  Medium    Basic     2     7     1
# 9997  81.567839      3      5    High    Basic     1     6     1
# 9998  89.885656      4      5     Low    Basic     2     0     1
# 9999  64.811297      4      5     Low  Premium     0     3     0
#
# [10000 rows x 15 columns]

# %% [markdown]
# 소수점이 있는 데이터들은 정수로 바꿔줘도 괜찮을거 같다

# %%
df['평균접속시간'] = df['평균접속시간'].round(0).astype(int)
df['학습평균시간(분)'] = df['학습평균시간(분)'].round(0).astype(int)
df['학습성취도'] = df['학습성취도'].round(0).astype(int)

df
# Out:
#            아이디  가입기간(월)  최종로그인(일)  평균접속시간  학습평균시간(분)  월간학습일  완료코스  학습성취도  \
# 0     b919c29d       13        14      15          8     18    16     68
# 1     a0a60abb       16        18      18         73     16    13     98
# 2     b9f171ae       22         1      16         22     13    14     94
# 3     5dc0ba8b        1        19      18         43     19    18     70
# 4     65c83654        4         5      21         31     19    10     82
# ...        ...      ...       ...     ...        ...    ...   ...    ...
# 9995  ae6b76bc       22        29      15         84     18    16     65
# 9996  24588752       10        11      19         45      9     8     83
# 9997  e4622a54        7        27      18        127     24    14     82
# 9998  e07fbad9       11         7      19          5     10    10     90
# 9999  e12dcb55       10         5      13         28      3    13     65
#
#       중단학습수  커뮤참여도    선호난도     구독유형  문의이력  결제패턴  연장여부
# 0         3      4     Low    Basic     4     5     0
# 1         2      3  Medium    Basic     1     6     1
# 2         3      4  Medium  Premium     0     7     1
# 3         0      3     Low    Basic     1     0     1
# 4         2      4  Medium    Basic     3     0     1
# ...     ...    ...     ...      ...   ...   ...   ...
# 9995      2      5     Low  Premium     1     1     1
# 9996      3      3  Medium    Basic     2     7     1
# 9997      3      5    High    Basic     1     6     1
# 9998      4      5     Low    Basic     2     0     1
# 9999      4      5     Low  Premium     0     3     0
#
# [10000 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   아이디        10000 non-null  object
#  1   가입기간(월)    10000 non-null  int64
#  2   최종로그인(일)   10000 non-null  int64
#  3   평균접속시간     10000 non-null  int32
#  4   학습평균시간(분)  10000 non-null  int32
#  5   월간학습일      10000 non-null  int64
#  6   완료코스       10000 non-null  int64
#  7   학습성취도      10000 non-null  int32
#  8   중단학습수      10000 non-null  int64
#  9   커뮤참여도      10000 non-null  int64
#  10  선호난도       10000 non-null  object
#  11  구독유형       10000 non-null  object
#  12  문의이력       10000 non-null  int64
#  13  결제패턴       10000 non-null  int64
#  14  연장여부       10000 non-null  int64
# dtypes: int32(3), int64(9), object(3)
# memory usage: 1.0+ MB

# %%
df.describe(include = 'all')
# Out:
#              아이디       가입기간(월)      최종로그인(일)        평균접속시간     학습평균시간(분)  \
# count      10000  10000.000000  10000.000000  10000.000000  10000.000000
# unique     10000           NaN           NaN           NaN           NaN
# top     b919c29d           NaN           NaN           NaN           NaN
# freq           1           NaN           NaN           NaN           NaN
# mean         NaN     11.897400     15.013200     14.995200     54.911800
# std          NaN      6.600896      8.362573      3.018325     56.023837
# min          NaN      1.000000      1.000000      2.000000      0.000000
# 25%          NaN      6.000000      8.000000     13.000000     15.000000
# 50%          NaN     12.000000     15.000000     15.000000     38.000000
# 75%          NaN     18.000000     22.000000     17.000000     76.000000
# max          NaN     23.000000     29.000000     27.000000    503.000000
#
#                월간학습일          완료코스         학습성취도         중단학습수         커뮤참여도  \
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       12.545400     12.227500     75.026600      3.043600      3.886100
# std         6.932239      3.634125      9.973046      1.755052      1.262175
# min         1.000000      1.000000     36.000000      0.000000      1.000000
# 25%         7.000000     10.000000     68.000000      2.000000      3.000000
# 50%        13.000000     12.000000     75.000000      3.000000      4.000000
# 75%        19.000000     15.000000     82.000000      4.000000      5.000000
# max        24.000000     27.000000    113.000000     12.000000      5.000000
#
#          선호난도   구독유형          문의이력          결제패턴          연장여부
# count   10000  10000  10000.000000  10000.000000  10000.000000
# unique      3      2           NaN           NaN           NaN
# top       Low  Basic           NaN           NaN           NaN
# freq     4992   5979           NaN           NaN           NaN
# mean      NaN    NaN      2.010500      3.502900      0.619900
# std       NaN    NaN      1.420983      2.311261      0.485435
# min       NaN    NaN      0.000000      0.000000      0.000000
# 25%       NaN    NaN      1.000000      1.000000      0.000000
# 50%       NaN    NaN      2.000000      4.000000      1.000000
# 75%       NaN    NaN      3.000000      6.000000      1.000000
# max       NaN    NaN     10.000000      7.000000      1.000000

# %%
df.describe()
# Out:
#             가입기간(월)      최종로그인(일)        평균접속시간     학습평균시간(분)         월간학습일  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      11.897400     15.013200     14.995200     54.911800     12.545400
# std        6.600896      8.362573      3.018325     56.023837      6.932239
# min        1.000000      1.000000      2.000000      0.000000      1.000000
# 25%        6.000000      8.000000     13.000000     15.000000      7.000000
# 50%       12.000000     15.000000     15.000000     38.000000     13.000000
# 75%       18.000000     22.000000     17.000000     76.000000     19.000000
# max       23.000000     29.000000     27.000000    503.000000     24.000000
#
#                완료코스         학습성취도         중단학습수         커뮤참여도          문의이력  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      12.227500     75.026600      3.043600      3.886100      2.010500
# std        3.634125      9.973046      1.755052      1.262175      1.420983
# min        1.000000     36.000000      0.000000      1.000000      0.000000
# 25%       10.000000     68.000000      2.000000      3.000000      1.000000
# 50%       12.000000     75.000000      3.000000      4.000000      2.000000
# 75%       15.000000     82.000000      4.000000      5.000000      3.000000
# max       27.000000    113.000000     12.000000      5.000000     10.000000
#
#                결제패턴          연장여부
# count  10000.000000  10000.000000
# mean       3.502900      0.619900
# std        2.311261      0.485435
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        4.000000      1.000000
# 75%        6.000000      1.000000
# max        7.000000      1.000000

# %% [markdown]
# 평균접속시간(사용자의 일반적인 로그인 시간) 이 27시? 24시간이 넘어갈수도 있나? 24시 이상인 데이터를 확인해보자

# %%
df[df['평균접속시간']>=24]
# Out:
#            아이디  가입기간(월)  최종로그인(일)  평균접속시간  학습평균시간(분)  월간학습일  완료코스  학습성취도  \
# 142   5ad41276       20        12      25          5      7     2     86
# 436   f89054f0       11        16      24         26     13    11     90
# 996   1c53992c        7        16      24        119     17     9     58
# 1020  e6b7f442        5        14      24         43      4    11     65
# 1123  6133388b       19         2      24        117      6    11     84
# 1195  38608e74       15        24      24        121     10    14     84
# 1831  d73a1cb2       22        12      24         44      5    16     83
# 1954  8fb3f7bf        7        18      24         48     20    14     57
# 2894  29f8d7db       16        19      25         39      7    14     83
# 2967  b57f0ca4        4        14      25         12     12    10     77
# 3255  55abb620       21        18      25        188      6    15     57
# 3317  56898140       21         9      24         64     21    13     84
# 3342  61c2daeb        5         3      25         78      2    20     82
# 3367  17363776        5         9      24          8     11    11     79
# 3465  c0cab5b4       14        12      24        120     12    16     74
# 3525  797c23b7       14        12      24         71      3    14     79
# 3560  9f820c9c       10        19      27         28     18    15     67
# 3738  3f948fa7        2        28      24         30     16    20     75
# 4434  26b8fd95        1        24      26         93     12    16     82
# 4844  5bb7f446       15         2      24        216     10    14     78
# 5030  c6b8a9ee        1         6      25         62     22    12     80
# 6025  88245fec       16        10      26         81     21     9     57
# 6387  cf1c648e       22        12      24         27      7    16     99
# 6752  8a9c160c        8        23      24          8      6    16     66
# 6762  ac4f9ac5        5         9      24          5      4    14     70
# 7521  acfb6ec8       19        21      25         28     24     3     74
# 8211  1834bf18       14        29      24          0      9     9     70
# 8609  e39f0a48       11        16      26        200     16    10     82
# 8699  9b6cf750       11         3      24          1     10    11     63
#
#       중단학습수  커뮤참여도    선호난도     구독유형  문의이력  결제패턴  연장여부
# 142       5      5  Medium    Basic     2     5     0
# 436       2      3     Low    Basic     2     5     1
# 996       5      4     Low  Premium     1     1     1
# 1020      3      3     Low    Basic     1     2     0
# 1123      0      5    High  Premium     4     6     1
# 1195      4      5  Medium  Premium     3     2     0
# 1831      1      5     Low  Premium     2     1     0
# 1954      1      2     Low    Basic     3     2     0
# 2894      1      2     Low    Basic     2     4     1
# 2967      3      5    High    Basic     3     6     1
# 3255      4      5  Medium  Premium     0     6     1
# 3317      3      5     Low  Premium     1     1     1
# 3342      0      5     Low  Premium     5     4     1
# 3367      4      5  Medium  Premium     3     1     0
# 3465      2      5     Low  Premium     2     6     1
# 3525      3      5     Low    Basic     4     2     0
# 3560      3      5     Low  Premium     1     7     0
# 3738      1      5     Low  Premium     4     3     1
# 4434      2      4  Medium  Premium     2     2     0
# 4844      3      5     Low  Premium     2     3     1
# 5030      2      5  Medium    Basic     4     5     0
# 6025      4      2     Low    Basic     2     0     1
# 6387      3      3  Medium  Premium     3     6     1
# 6752      2      4  Medium  Premium     2     5     0
# 6762      3      2     Low    Basic     1     0     0
# 7521      4      3  Medium    Basic     1     7     1
# 8211      6      2    High    Basic     4     4     0
# 8609      1      3  Medium  Premium     2     7     1
# 8699      5      3  Medium  Premium     1     1     1

# %% [markdown]
# 전체 데이터 대비 많은 비율은 아닌거 같다. 빼볼까.......?

# %%
df = df[df['평균접속시간'] < 24]

# %% [markdown]
# 학습평균시간(분)(각 학습 세션에 소요된 평균 시간 (분)) 이 큰 애들은 이상치일까..? 근데 너무 많은거 같기도 하고..복습했을 수도 있을까? 일단 자세한 정보가 없으니 넘어가자

# %%
df['학습평균시간(분)'].sort_values(ascending = False).head(100)
# Out:
# 4657    503
# 472     490
# 9410    470
# 2593    447
# 1764    444
#        ...
# 5677    259
# 9240    258
# 5267    256
# 5125    256
# 9185    256
# Name: 학습평균시간(분), Length: 100, dtype: int32

# %% [markdown]
# 학습 성취도는 100이 만점이 아닌건가?음...놔둬도 크게 영향은 없을거 같다..

# %%
df[df['학습성취도'] > 100]
# Out:
#            아이디  가입기간(월)  최종로그인(일)  평균접속시간  학습평균시간(분)  월간학습일  완료코스  학습성취도  \
# 37    5ae7bf2c       15         9      18         50     15     8    104
# 243   abce9494        4         6      18         23     24    13    104
# 333   b0822fbe       11        14      16         19      7     9    103
# 547   c9832f16       11        23      12         73     15     8    105
# 687   4f39fecb       14        24      19         15      3     9    101
# 791   2b47d1d6       13         5      17          4      1    13    101
# 890   ae1a40b9       23        23      14         43     13     9    102
# 905   281395b2        2        14      18         30      8    10    102
# 1149  4f998292        1        14      17         84      3    10    102
# 1321  dee60f35       13        25      15         92      6    10    102
# 1439  28df69bf       16        29      14          1      7    15    101
# 1457  740b55e6       10        23      16         91     10    12    102
# 1591  bda4e76f       19        11      18         21      9     9    106
# 1743  79613f66       15        25      13        148     17    13    103
# 1901  ec201366        8         7      12         62     12    11    101
# 2188  6b263724       10        12      13          3      6    10    103
# 2274  63e12518        6        22      20          3      8    20    106
# 2561  4747f01f       18         5      12        119      9    10    111
# 2714  9d0f7d8a       13         4      14         88     20    16    102
# 3410  c643a18f       11         8      20          9     18     7    101
# 4134  719dff67       14        12      18         53     21     7    102
# 4289  a2e7218d        3        27      15         59      3    12    105
# 4632  43d97f95        6        19      16         32     10    12    101
# 5061  ee1c986c        9         4      14         33     17    15    101
# 5220  6a664b7d       11        15      19         22      8    16    102
# 5390  b0c92ddf       15        12      17        100     22    21    107
# 5394  133671ad       13         5      13         53     24    15    105
# 5843  2fe8c64d       14        15      17         16      4    13    113
# 6099  91971f04        4         6      15         50      3     9    105
# 6281  8b5a7001       23         5      19          4     17    12    102
# 6806  2e82b18f       16        16      11          8     18     9    101
# 7148  b723b8eb       19        16      16         30     15    14    108
# 7506  c8dafb73       11        19      20          9      4    14    104
# 7846  609545b9       12        23      11          8     21    15    101
# 7861  b8b32528       12        24      14         37     22    17    107
# 7922  66c76d57        5        26      14         30     12     8    101
# 7981  57c65679       12         1      17         95      8    15    105
# 8314  b61ca4ff       18        10      13          3     24    15    101
# 8322  1fb7d4f4       16        27      12         52     15    13    102
# 8394  9299c2fe       17         4      13         30     10    12    110
# 8549  2fede28e        9        10      17         13     14    16    101
# 9033  5252522e        1        27      11         15     22    17    101
# 9231  7326c6e6        1         9      17         21     18    13    103
# 9681  c12217ba        9        13      17          2     12    18    101
# 9683  84c65470       20        19      17         35     22     6    101
# 9719  21baebce       12        19      11         89     12    13    103
# 9727  c27c67e9       11        22      13        167      3     8    101
#
#       중단학습수  커뮤참여도    선호난도     구독유형  문의이력  결제패턴  연장여부
# 37        2      3  Medium    Basic     2     0     0
# 243       1      3  Medium  Premium     1     4     1
# 333       2      3  Medium    Basic     3     6     0
# 547       3      3     Low    Basic     3     4     1
# 687       3      5     Low    Basic     2     2     1
# 791       2      5     Low    Basic     3     2     1
# 890       5      3  Medium    Basic     2     6     1
# 905       4      3     Low    Basic     1     7     1
# 1149      5      2     Low    Basic     0     5     0
# 1321      2      2     Low    Basic     1     4     1
# 1439      0      5    High  Premium     3     4     0
# 1457      5      5    High    Basic     3     2     1
# 1591      3      5  Medium  Premium     4     3     1
# 1743      3      3    High  Premium     2     3     1
# 1901      1      1  Medium    Basic     3     4     0
# 2188      6      4     Low    Basic     0     2     1
# 2274      1      4  Medium    Basic     2     0     0
# 2561      2      2  Medium    Basic     5     2     1
# 2714      5      4     Low  Premium     2     4     0
# 3410      1      4  Medium    Basic     0     5     1
# 4134      7      2     Low    Basic     3     7     0
# 4289      4      4    High    Basic     1     7     0
# 4632      7      4  Medium  Premium     1     2     0
# 5061      2      4     Low  Premium     2     6     1
# 5220      5      5     Low    Basic     2     2     0
# 5390      5      5     Low  Premium     1     6     0
# 5394      3      5     Low  Premium     2     7     1
# 5843      3      5     Low  Premium     0     2     1
# 6099      2      2    High    Basic     1     5     1
# 6281      0      3     Low    Basic     2     0     1
# 6806      2      2    High    Basic     3     0     1
# 7148      3      5     Low  Premium     2     2     1
# 7506      2      5     Low    Basic     2     3     0
# 7846      4      5    High    Basic     1     6     0
# 7861      2      4    High  Premium     0     3     0
# 7922      4      1    High    Basic     5     4     1
# 7981      6      4     Low    Basic     3     3     0
# 8314      2      4     Low    Basic     0     6     0
# 8322      2      5    High  Premium     1     7     1
# 8394      4      4     Low  Premium     3     2     1
# 8549      4      5     Low  Premium     0     5     1
# 9033      4      1    High    Basic     1     5     0
# 9231      1      5     Low    Basic     2     2     0
# 9681      3      5    High  Premium     0     1     1
# 9683      1      4     Low    Basic     1     4     1
# 9719      7      2     Low    Basic     2     0     1
# 9727      3      3     Low    Basic     1     1     1

# %% [markdown]
# 세션과 코스의 의미가 같다는 가정하에 월 접속시간을 계산해보자. 동일하지는 않더라고 비례하는 값이 나오겠지?

# %%
df['월접속시간(분)'] = df['학습평균시간(분)'] * df['완료코스']
df.head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3004\963647270.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['월접속시간(분)'] = df['학습평균시간(분)'] * df['완료코스']
#         아이디  가입기간(월)  최종로그인(일)  평균접속시간  학습평균시간(분)  월간학습일  완료코스  학습성취도  중단학습수  \
# 0  b919c29d       13        14      15          8     18    16     68      3
# 1  a0a60abb       16        18      18         73     16    13     98      2
# 2  b9f171ae       22         1      16         22     13    14     94      3
# 3  5dc0ba8b        1        19      18         43     19    18     70      0
# 4  65c83654        4         5      21         31     19    10     82      2
#
#    커뮤참여도    선호난도     구독유형  문의이력  결제패턴  연장여부  월접속시간(분)
# 0      4     Low    Basic     4     5     0       128
# 1      3  Medium    Basic     1     6     1       949
# 2      4  Medium  Premium     0     7     1       308
# 3      3     Low    Basic     1     0     1       774
# 4      4  Medium    Basic     3     0     1       310

# %% [markdown]
# 요고를 월간학습일로 나누면 접속시 평균학습시간?

# %%
df['평균학습시간(분)'] = (df['월접속시간(분)'] / df['월간학습일']).astype(int)
df
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3004\3526766575.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['평균학습시간(분)'] = (df['월접속시간(분)'] / df['월간학습일']).astype(int)
#            아이디  가입기간(월)  최종로그인(일)  평균접속시간  학습평균시간(분)  월간학습일  완료코스  학습성취도  \
# 0     b919c29d       13        14      15          8     18    16     68
# 1     a0a60abb       16        18      18         73     16    13     98
# 2     b9f171ae       22         1      16         22     13    14     94
# 3     5dc0ba8b        1        19      18         43     19    18     70
# 4     65c83654        4         5      21         31     19    10     82
# ...        ...      ...       ...     ...        ...    ...   ...    ...
# 9995  ae6b76bc       22        29      15         84     18    16     65
# 9996  24588752       10        11      19         45      9     8     83
# 9997  e4622a54        7        27      18        127     24    14     82
# 9998  e07fbad9       11         7      19          5     10    10     90
# 9999  e12dcb55       10         5      13         28      3    13     65
#
#       중단학습수  커뮤참여도    선호난도     구독유형  문의이력  결제패턴  연장여부  월접속시간(분)  평균학습시간(분)
# 0         3      4     Low    Basic     4     5     0       128          7
# 1         2      3  Medium    Basic     1     6     1       949         59
# 2         3      4  Medium  Premium     0     7     1       308         23
# 3         0      3     Low    Basic     1     0     1       774         40
# 4         2      4  Medium    Basic     3     0     1       310         16
# ...     ...    ...     ...      ...   ...   ...   ...       ...        ...
# 9995      2      5     Low  Premium     1     1     1      1344         74
# 9996      3      3  Medium    Basic     2     7     1       360         40
# 9997      3      5    High    Basic     1     6     1      1778         74
# 9998      4      5     Low    Basic     2     0     1        50          5
# 9999      4      5     Low  Premium     0     3     0       364        121
#
# [9971 rows x 17 columns]

# %%
df['평균학습시간(분)'].max()
# Out:
# 6045

# %% [markdown]
# 한번에 6천분은..흠...1회당 평균 학습시간은 아닌가부다..

# %% [markdown]
# # 어떤 데이터가 구독연장여부와 관계가 있을까?

# %%
a = df['선호난도'].value_counts()
sns.barplot(x = a.index, y = a.values)

for i, count in enumerate(a.values) :
    plt.text(i, count + 0.1, str(count), ha='center', va = 'bottom')

plt.show()

# %% [markdown]
# ## 당연한 얘기일수도 있지만 난이도가 낮을 수록 선호도가 높은 것을 확인할 수 있었다. Low 레벨의 콘텐츠 양에도 집중해야겠지만 자연스럽게 다음 레벨로 넘어갈 수 있도록 커리큘럼을 디자인해야겠다.

# %%
b = df['구독유형'].value_counts()
sns.barplot(x = b.index, y = b.values)

for i, count in enumerate(b.values) :
    plt.text(i, count + 0.1, str(count), ha='center', va = 'bottom')

plt.show()

# %%
plt.hist(df['가입기간(월)'], bins=24)
plt.xlabel('가입기간(월)')
plt.ylabel('회원수')
plt.title('가입기간(월) 분포')
plt.show()

# %%
df['연장여부'].value_counts()
# Out:
# 연장여부
# 1    6183
# 0    3788
# Name: count, dtype: int64

# %%
nums = df.groupby('선호난도')['연장여부'].value_counts()

bar = sns.countplot(x = '선호난도', hue = '연장여부', data = df)

for i in bar.patches :
    height = i.get_height()
    bar.text(i.get_x() + i.get_width() / 2, height + 50, f'{int(height)}', ha = 'center')
    
plt.show()

# %%
plt.hist(df['학습평균시간(분)'], bins=10)
plt.show()

# %%
plt.hist(df['평균접속시간'], bins=24)
plt.show()

# %%
df['평균접속시간'].value_counts().sort_index()
# Out:
# 평균접속시간
# 2        1
# 3        2
# 4        2
# 5        7
# 6       11
# 7       47
# 8       86
# 9      175
# 10     342
# 11     522
# 12     819
# 13    1028
# 14    1321
# 15    1343
# 16    1268
# 17    1000
# 18     804
# 19     544
# 20     344
# 21     189
# 22      75
# 23      41
# Name: count, dtype: int64

# %%
x = df['평균접속시간'].value_counts()[range(9, 19)].sum()

ratio = x / df['평균접속시간'].value_counts().sum()

ratio
# Out:
# 0.8647076521913549

# %% [markdown]
# ## hist 중간에 왜 비는지는..못찾겠다. 아마 데이터형태를 변환해주는 과정에서 뭔가 오류가 있었던거 같긴 한데..못찾겠다..아무튼 우리 플랫폼은 9시부터 접속자가 증가하며 14시~15시 사이에 피크를 찍고 점차 감소하고 있다. 9-18시 사이의 사용자가 86.5%에 달하는 만큼 이 시간에 발생하는 고객문의, 커뮤니티 관리 등 고객 관리에 집중할 필요가 있겠다.

# %%
plt.hist(df['최종로그인(일)'], bins=31)
plt.xticks(range(0, 31))
plt.show()

# %% [markdown]
# ## 에라이. 지표도 많은데 하나씩 보니깐 너무 오래 걸릴거 같다. 한번에 다 찍어보자.

# %%
# sns.pairplot(df) # 되게 오래 걸리네. 이미지는 저장했으니 주석처리 해주자

# %% [markdown]
# 여러가지 지표를 연장여부와 상관관계를 나타내보았지만, 유일하게 눈에 띄는 지표는 학습평균시간(각 학습 세션에 소요된 평균 시간 (분)) 과의 추이였다. 학습평균시간(분)이 일정 수치가 넘어서는 사용자는 구독을 100% 연장하였다. '학습평균시간(분)'이라는 지표는 어떤 의미가 있을까?

# %%
plt.scatter(df['학습평균시간(분)'], df['연장여부'])

# %%
plt.figure(figsize=(8, 5))
sns.lineplot(x='학습평균시간(분)', y='연장여부', data=df, marker='o')
plt.title('학습평균시간별 연장 여부 추이')
plt.xlabel('학습평균시간(분)')
plt.ylabel('연장 여부')
plt.grid(True)
plt.show()

# %%
df[df['학습평균시간(분)']>178]['연장여부'].min()
# Out:
# 0

# %%
df[df['학습평균시간(분)']>179]['연장여부'].min()
# Out:
# 1

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='평균학습시간(분)', y='연장여부', data=df, marker='o')
plt.title('평균학습시간(분)별 연장 여부 추이')
plt.xlabel('평균학습시간(분)')
plt.ylabel('연장 여부')
plt.grid(True)
plt.show()

# %%
df[df['월접속시간(분)']>3057]['연장여부'].min()
# Out:
# 0

# %%
df[df['월접속시간(분)']>3058]['연장여부'].min()
# Out:
# 1

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='월접속시간(분)', y='연장여부', data=df, marker='o')
plt.title('월접속시간(분)별 연장 여부 추이')
plt.xlabel('월접속시간(분)')
plt.ylabel('연장 여부')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 학습평균시간이 일정수치 이상인 사람은 연장을 취소하지 않는다????? 학습에 오래 걸릴수록 연장을 한다??????????????? 범주형 데이터와의 관계를 다시 확인해보자

# %% [markdown]
# 구독유형과 선호난도가 연장여부에 어떤 영향을 미치는지 확인해보자

# %%
df.pivot_table(values = '연장여부', index = '구독유형', columns = '선호난도')
# Out:
# 선호난도         High       Low    Medium
# 구독유형
# Basic    0.623980  0.604930  0.630822
# Premium  0.614786  0.618734  0.643084

# %% [markdown]
# 이중인덱스로 비교해보자

# %%
df.pivot_table(index = ['구독유형', '선호난도'], values = '연장여부', aggfunc = 'mean')
# Out:
#                     연장여부
# 구독유형    선호난도
# Basic   High    0.623980
#         Low     0.604930
#         Medium  0.630822
# Premium High    0.614786
#         Low     0.618734
#         Medium  0.643084

# %% [markdown]
# 학습평균시간과도 비교해보자

# %%
pivot_df = df.pivot_table(values='학습평균시간(분)', index='선호난도', columns='구독유형', aggfunc='mean')
pivot_df
# Out:
# 구독유형        Basic    Premium
# 선호난도
# High    42.796900  57.214008
# Low     52.604930  70.910886
# Medium  45.179413  58.918124

# %% [markdown]
# 조금 유의미하게 눈에 띄는 차이가 있는거 같다. 히트맵을 찍어보자

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(pivot_df, annot = True, fmt = ".3f", cmap = 'BuGn', annot_kws = {"size": 12, "weight": "bold"})

plt.xticks(fontsize = 12, weight = 'bold')
plt.yticks(fontsize = 12, weight = 'bold')

plt.title('구독유형 및 선호난도별 학습평균시간(분)')
plt.xlabel('구독유형', fontsize = 15, weight = 'bold', labelpad = 20)
plt.ylabel('선호난도', fontsize = 15, weight = 'bold', labelpad = 20)
plt.show()

# %%
df['구독유형'].value_counts()
# Out:
# 구독유형
# Basic      5967
# Premium    4004
# Name: count, dtype: int64

# %%
df['연장여부'].value_counts()
# Out:
# 연장여부
# 1    6183
# 0    3788
# Name: count, dtype: int64

# %% [markdown]
# ## 학습평균시간이 일정수치 이상일 때 구독을 연장한다고 가정하였을때, 구독 유형에 따라 학습평균시간이 유의미하게 증가하는 것을 확인 할 수 있었다.
#
# ## Basic 과 Premium 의 비율이 6 : 4 정도인데 Premium 의 비율을 늘린다면 구독 연장에 유의미하게 영향이 있지 않을까? 구독 유형에 따른 지표를 분석해보자

# %%
df.pivot_table(index = ['선호난도', '구독유형'], values = ['학습평균시간(분)', '커뮤참여도', '완료코스'], aggfunc = 'mean')
# Out:
#                      완료코스     커뮤참여도  학습평균시간(분)
# 선호난도   구독유형
# High   Basic    10.002447  3.061990  42.796900
#        Premium  13.114137  4.399481  57.214008
# Low    Basic    12.088274  3.795470  52.604930
#        Premium  15.064304  4.797468  70.910886
# Medium Basic     9.883841  3.025877  45.179413
#        Premium  12.961844  4.347377  58.918124

# %% [markdown]
# Premium이 Basic에 비해 눈에 띄게 차이나는 지표는 '완료코스', '커뮤참여도', '학습평균시간(분)' 3가지였다.

# %%
selected_columns = ['구독유형', '완료코스', '커뮤참여도', '학습평균시간(분)']
df_selected = df[selected_columns]

df_selected['구독유형'] = df_selected['구독유형'].apply(lambda x: 1 if x == 'Premium' else 0)

corr_matrix = df_selected.corr()

plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(corr_matrix, annot=True, cmap='YlOrBr', fmt='.2f', annot_kws={"size": 10})
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3004\109497957.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['구독유형'] = df_selected['구독유형'].apply(lambda x: 1 if x == 'Premium' else 0)

# %%
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(corr_matrix, annot=True, cmap='Reds', fmt='.2f', mask=mask, annot_kws={"size": 10})
plt.show()

# %% [markdown]
# ## Premium 사용자가 완료코스, 커뮤참여도 부분에서 눈에 띄게 활동적인 것을 알 수 있었다. 학습평균시간(분) 에서도 소폭 영향이 있었다. Basic 회원에 비해 Premium 회원이 서비스에 대한 만족도가 높으리라 예상됩니다.
#
# ## 가격적인 진입장벽을 잠시 낮춰서 Basic 사용자를 Premium 구독으로 전환한다면 상당수 만족도를 느끼고 구독 유형을 Premium 으로 유지할 수 있지 않을까?
#
# ## Basic 유저에게는 3개월간 Premium으로 구독을 업그레이드해주고 신규고객에게는 Basic 가격으로 Premium 구독을 제공하면 신규/기존 회원 모두에게 효과적인 프로모션이 될 것으로 예상됩니다.

# %%
df
# Out:
#            아이디  가입기간(월)  최종로그인(일)  평균접속시간  학습평균시간(분)  월간학습일  완료코스  학습성취도  \
# 0     b919c29d       13        14      15          8     18    16     68
# 1     a0a60abb       16        18      18         73     16    13     98
# 2     b9f171ae       22         1      16         22     13    14     94
# 3     5dc0ba8b        1        19      18         43     19    18     70
# 4     65c83654        4         5      21         31     19    10     82
# ...        ...      ...       ...     ...        ...    ...   ...    ...
# 9995  ae6b76bc       22        29      15         84     18    16     65
# 9996  24588752       10        11      19         45      9     8     83
# 9997  e4622a54        7        27      18        127     24    14     82
# 9998  e07fbad9       11         7      19          5     10    10     90
# 9999  e12dcb55       10         5      13         28      3    13     65
#
#       중단학습수  커뮤참여도    선호난도     구독유형  문의이력  결제패턴  연장여부  월접속시간(분)  평균학습시간(분)
# 0         3      4     Low    Basic     4     5     0       128          7
# 1         2      3  Medium    Basic     1     6     1       949         59
# 2         3      4  Medium  Premium     0     7     1       308         23
# 3         0      3     Low    Basic     1     0     1       774         40
# 4         2      4  Medium    Basic     3     0     1       310         16
# ...     ...    ...     ...      ...   ...   ...   ...       ...        ...
# 9995      2      5     Low  Premium     1     1     1      1344         74
# 9996      3      3  Medium    Basic     2     7     1       360         40
# 9997      3      5    High    Basic     1     6     1      1778         74
# 9998      4      5     Low    Basic     2     0     1        50          5
# 9999      4      5     Low  Premium     0     3     0       364        121
#
# [9971 rows x 17 columns]

# %% [markdown]
# # 결제패턴이 7(3개월 모두 결제함) 인 회원을 가장 안정적이고 서비스에 만족하고 있다고 가정해보자. 다른 결제패턴의 사용자와 어떻게 다른 패턴을 보이는지, 특히 0(3개월 동안 결제하지 않음) 과는 어떤 차이를 보이는지 찾아보자

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9971 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   아이디        9971 non-null   object
#  1   가입기간(월)    9971 non-null   int64
#  2   최종로그인(일)   9971 non-null   int64
#  3   평균접속시간     9971 non-null   int32
#  4   학습평균시간(분)  9971 non-null   int32
#  5   월간학습일      9971 non-null   int64
#  6   완료코스       9971 non-null   int64
#  7   학습성취도      9971 non-null   int32
#  8   중단학습수      9971 non-null   int64
#  9   커뮤참여도      9971 non-null   int64
#  10  선호난도       9971 non-null   object
#  11  구독유형       9971 non-null   object
#  12  문의이력       9971 non-null   int64
#  13  결제패턴       9971 non-null   int64
#  14  연장여부       9971 non-null   int64
#  15  월접속시간(분)   9971 non-null   int64
#  16  평균학습시간(분)  9971 non-null   int32
# dtypes: int32(4), int64(10), object(3)
# memory usage: 1.2+ MB

# %%
df.describe(include = 'all')
# Out:
#              아이디      가입기간(월)     최종로그인(일)       평균접속시간    학습평균시간(분)  \
# count       9971  9971.000000  9971.000000  9971.000000  9971.000000
# unique      9971          NaN          NaN          NaN          NaN
# top     b919c29d          NaN          NaN          NaN          NaN
# freq           1          NaN          NaN          NaN          NaN
# mean         NaN    11.897804    15.015545    14.967405    54.882760
# std          NaN     6.600924     8.365333     2.977994    56.010663
# min          NaN     1.000000     1.000000     2.000000     0.000000
# 25%          NaN     6.000000     8.000000    13.000000    15.000000
# 50%          NaN    12.000000    15.000000    15.000000    38.000000
# 75%          NaN    18.000000    22.000000    17.000000    76.000000
# max          NaN    23.000000    29.000000    23.000000   503.000000
#
#               월간학습일         완료코스        학습성취도        중단학습수        커뮤참여도  선호난도  \
# count   9971.000000  9971.000000  9971.000000  9971.000000  9971.000000  9971
# unique          NaN          NaN          NaN          NaN          NaN     3
# top             NaN          NaN          NaN          NaN          NaN   Low
# freq            NaN          NaN          NaN          NaN          NaN  4977
# mean      12.548691    12.226356    75.025674     3.044429     3.885869   NaN
# std        6.933971     3.632989     9.971401     1.755613     1.262376   NaN
# min        1.000000     1.000000    36.000000     0.000000     1.000000   NaN
# 25%        7.000000    10.000000    68.000000     2.000000     3.000000   NaN
# 50%       13.000000    12.000000    75.000000     3.000000     4.000000   NaN
# 75%       19.000000    15.000000    82.000000     4.000000     5.000000   NaN
# max       24.000000    27.000000   113.000000    12.000000     5.000000   NaN
#
#          구독유형         문의이력         결제패턴         연장여부     월접속시간(분)    평균학습시간(분)
# count    9971  9971.000000  9971.000000  9971.000000  9971.000000  9971.000000
# unique      2          NaN          NaN          NaN          NaN          NaN
# top     Basic          NaN          NaN          NaN          NaN          NaN
# freq     5967          NaN          NaN          NaN          NaN          NaN
# mean      NaN     2.009628     3.502658     0.620098   687.499448   107.359743
# std       NaN     1.421467     2.311471     0.485386   780.734344   248.513748
# min       NaN     0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       NaN     1.000000     1.000000     0.000000   169.000000    14.000000
# 50%       NaN     2.000000     4.000000     1.000000   432.000000    39.000000
# 75%       NaN     3.000000     6.000000     1.000000   912.000000    97.000000
# max       NaN    10.000000     7.000000     1.000000  8551.000000  6045.000000

# %%
df1 = df.sort_values(by = '결제패턴', ascending = False)
df1
# Out:
#            아이디  가입기간(월)  최종로그인(일)  평균접속시간  학습평균시간(분)  월간학습일  완료코스  학습성취도  \
# 5005  27ec531b       11        18      15         42     21    11     73
# 6491  33867fb1       16        19      10         34     17     8     85
# 6499  f535535d        6        14      13         57     16     8     76
# 6502  548d674b       21        22      19          7     23     9     76
# 6504  fc7c1cf7        7        11      15         45      1    12     67
# ...        ...      ...       ...     ...        ...    ...   ...    ...
# 6270  b24d855c       17         1      17         15      6    15     73
# 8905  e65067f2        2        12       9         58     16    15     74
# 4009  be155f2b       19        23      10         33      4    18     92
# 2216  926604cf       14        20      15         74      6    17     85
# 8529  150f7d06        8        23      19         31     10    13     81
#
#       중단학습수  커뮤참여도    선호난도     구독유형  문의이력  결제패턴  연장여부  월접속시간(분)  평균학습시간(분)
# 5005      3      5  Medium    Basic     4     7     1       462         22
# 6491      4      3     Low    Basic     0     7     1       272         16
# 6499      0      5     Low    Basic     1     7     1       456         28
# 6502      2      3    High  Premium     4     7     1        63          2
# 6504      1      1  Medium    Basic     1     7     1       540        540
# ...     ...    ...     ...      ...   ...   ...   ...       ...        ...
# 6270      0      4     Low  Premium     1     0     1       225         37
# 8905      2      5  Medium  Premium     2     0     1       870         54
# 4009      5      3  Medium  Premium     3     0     1       594        148
# 2216      0      4     Low    Basic     1     0     0      1258        209
# 8529      5      1  Medium    Basic     1     0     1       403         40
#
# [9971 rows x 17 columns]

# %%
df1['결제패턴'].value_counts()
# Out:
# 결제패턴
# 7    1281
# 1    1280
# 0    1273
# 6    1263
# 5    1234
# 3    1228
# 4    1211
# 2    1201
# Name: count, dtype: int64

# %%
df_pivot = df.pivot_table(index = ['결제패턴'], values = ['가입기간(월)', '최종로그인(일)', '평균접속시간', '학습평균시간(분)', '월간학습일', '완료코스', '학습성취도', '중단학습수', '커뮤참여도', '문의이력', '연장여부'], aggfunc = 'mean')
df_pivot
# Out:
#         가입기간(월)      문의이력      연장여부       완료코스      월간학습일     중단학습수  \
# 결제패턴
# 0     11.935585  1.996072  0.633150  12.238020  12.747840  2.934014
# 1     12.018750  2.051563  0.609375  12.364062  12.713281  3.020313
# 2     11.702748  2.000000  0.621982  12.212323  12.236470  3.167361
# 3     12.175081  2.004072  0.619707  12.343648  12.389251  3.057003
# 4     11.759703  2.042114  0.620149  12.168456  12.565648  3.001652
# 5     11.791734  1.913290  0.606969  12.111021  12.545381  3.083468
# 6     11.858274  2.014252  0.630245  12.192399  12.664291  3.036421
# 7     11.928181  2.053084  0.619048  12.177205  12.505074  3.061671
#
#        최종로그인(일)     커뮤참여도     평균접속시간      학습성취도  학습평균시간(분)
# 결제패턴
# 0     14.897093  3.881383  14.912019  74.895522  52.207384
# 1     14.847656  3.985156  15.000781  75.141406  57.803906
# 2     14.930058  3.879267  14.885928  75.632806  54.115737
# 3     15.350163  3.864007  14.863192  74.579805  55.578990
# 4     14.764657  3.880264  15.036334  75.011561  57.341866
# 5     15.128039  3.854133  15.007293  75.065640  54.623987
# 6     15.199525  3.886778  15.011876  74.911322  53.353919
# 7     15.007806  3.853240  15.017955  74.985168  54.106167

# %%
sns.heatmap(df_pivot, annot = True, cmap = 'Reds')
# Out:
# <Axes: ylabel='결제패턴'>

# %% [markdown]
# ## 음..이렇게 봐서는 크게 차이가 없는거 같다. 다른 지표와 비교해보자.

# %%
level = {'Low' : 0, 'Medium' : 1, 'High' : 2}
rate = {'Basic' : 0, 'Premium' : 1}

df1['선호난도'] = df['선호난도'].map(level)
df1['구독유형'] = df['구독유형'].map(rate)

df1
# Out:
#            아이디  가입기간(월)  최종로그인(일)  평균접속시간  학습평균시간(분)  월간학습일  완료코스  학습성취도  \
# 5005  27ec531b       11        18      15         42     21    11     73
# 6491  33867fb1       16        19      10         34     17     8     85
# 6499  f535535d        6        14      13         57     16     8     76
# 6502  548d674b       21        22      19          7     23     9     76
# 6504  fc7c1cf7        7        11      15         45      1    12     67
# ...        ...      ...       ...     ...        ...    ...   ...    ...
# 6270  b24d855c       17         1      17         15      6    15     73
# 8905  e65067f2        2        12       9         58     16    15     74
# 4009  be155f2b       19        23      10         33      4    18     92
# 2216  926604cf       14        20      15         74      6    17     85
# 8529  150f7d06        8        23      19         31     10    13     81
#
#       중단학습수  커뮤참여도  선호난도  구독유형  문의이력  결제패턴  연장여부  월접속시간(분)  평균학습시간(분)
# 5005      3      5     1     0     4     7     1       462         22
# 6491      4      3     0     0     0     7     1       272         16
# 6499      0      5     0     0     1     7     1       456         28
# 6502      2      3     2     1     4     7     1        63          2
# 6504      1      1     1     0     1     7     1       540        540
# ...     ...    ...   ...   ...   ...   ...   ...       ...        ...
# 6270      0      4     0     1     1     0     1       225         37
# 8905      2      5     1     1     2     0     1       870         54
# 4009      5      3     1     1     3     0     1       594        148
# 2216      0      4     0     0     1     0     0      1258        209
# 8529      5      1     1     0     1     0     1       403         40
#
# [9971 rows x 17 columns]

# %%
df1_pivot = df1.pivot_table(index = ['결제패턴'], values = ['선호난도', '구독유형'], aggfunc = 'mean')
df1_pivot
# Out:
#           구독유형      선호난도
# 결제패턴
# 0     0.402200  0.684996
# 1     0.435937  0.655469
# 2     0.422148  0.714405
# 3     0.418567  0.724756
# 4     0.370768  0.681255
# 5     0.376823  0.708266
# 6     0.394299  0.724466
# 7     0.391101  0.716628

# %%
sns.heatmap(df1_pivot, annot = True, cmap = 'Reds')
# Out:
# <Axes: ylabel='결제패턴'>

# %%
df1['구독유형'].mean(), df1['선호난도'].mean()
# Out:
# (0.4015645371577575, 0.7011332865309398)

# %%
df2 = df1[df1['결제패턴'] % 2 == 0]

df2_pivot = df2.pivot_table(index = ['결제패턴'], values = ['선호난도', '구독유형'], aggfunc = 'mean')
df2_pivot
# Out:
#           구독유형      선호난도
# 결제패턴
# 0     0.402200  0.684996
# 2     0.422148  0.714405
# 4     0.370768  0.681255
# 6     0.394299  0.724466

# %%
df2['구독유형'].mean(), df2['선호난도'].mean()
# Out:
# (0.3973322554567502, 0.7012934518997574)

# %%
df3 = df1[df1['결제패턴'] % 2 == 1]

df3_pivot = df3.pivot_table(index = ['결제패턴'], values = ['선호난도', '구독유형'], aggfunc = 'mean')
df3_pivot
# Out:
#           구독유형      선호난도
# 결제패턴
# 1     0.435937  0.655469
# 3     0.418567  0.724756
# 5     0.376823  0.708266
# 7     0.391101  0.716628

# %%
df3['구독유형'].mean(), df3['선호난도'].mean()
# Out:
# (0.40573362532351187, 0.7009755126418475)

# %% [markdown]
# ## 결제패턴이 1(마지막 달에만 결제함) 일 경우 다른 패턴에 비해 구독연장으로 이어지는 경우는 10%정도 증가하지만 선호난도는 5%정도 낮았다.
#
# ## 반대로 마지막 달에 결제하지 않은 경우(0, 2, 4, 6) 구독연장으로 이어지는 경우 소폭 하락하였다.
#
# ## 결제시스템이 1개월 단위로만 가능한지, 장기 구독이 가능한지 확인 할 수 없지만 마지막 달에 결제하였을 때 구독 연장으로 이어지는 경우가 소폭 증가함을 알 수 있었다. 마지막 달에 결제를 하지 않은 사용자에게 알림 메시지를 보내는 등 미리 결제를 할 수 있도록 유도해봐야겠다.

# %%
df1
# Out:
#            아이디  가입기간(월)  최종로그인(일)  평균접속시간  학습평균시간(분)  월간학습일  완료코스  학습성취도  \
# 5005  27ec531b       11        18      15         42     21    11     73
# 6491  33867fb1       16        19      10         34     17     8     85
# 6499  f535535d        6        14      13         57     16     8     76
# 6502  548d674b       21        22      19          7     23     9     76
# 6504  fc7c1cf7        7        11      15         45      1    12     67
# ...        ...      ...       ...     ...        ...    ...   ...    ...
# 6270  b24d855c       17         1      17         15      6    15     73
# 8905  e65067f2        2        12       9         58     16    15     74
# 4009  be155f2b       19        23      10         33      4    18     92
# 2216  926604cf       14        20      15         74      6    17     85
# 8529  150f7d06        8        23      19         31     10    13     81
#
#       중단학습수  커뮤참여도  선호난도  구독유형  문의이력  결제패턴  연장여부  월접속시간(분)  평균학습시간(분)
# 5005      3      5     1     0     4     7     1       462         22
# 6491      4      3     0     0     0     7     1       272         16
# 6499      0      5     0     0     1     7     1       456         28
# 6502      2      3     2     1     4     7     1        63          2
# 6504      1      1     1     0     1     7     1       540        540
# ...     ...    ...   ...   ...   ...   ...   ...       ...        ...
# 6270      0      4     0     1     1     0     1       225         37
# 8905      2      5     1     1     2     0     1       870         54
# 4009      5      3     1     1     3     0     1       594        148
# 2216      0      4     0     0     1     0     0      1258        209
# 8529      5      1     1     0     1     0     1       403         40
#
# [9971 rows x 17 columns]

# %%
df1_pivot = df1.pivot_table(index = ['평균접속시간'], values = ['가입기간(월)', '최종로그인(일)', '학습평균시간(분)', '월간학습일', '완료코스', '학습성취도', '중단학습수', '커뮤참여도', '선호난도', '구독유형', '문의이력', '결제패턴', '연장여부'], aggfunc = 'mean')
df1_pivot
# Out:
#           가입기간(월)      결제패턴      구독유형      문의이력      선호난도      연장여부  \
# 평균접속시간
# 2        8.000000  3.000000  0.000000  1.000000  2.000000  1.000000
# 3       18.500000  1.000000  0.000000  2.000000  0.000000  1.000000
# 4       10.500000  4.000000  0.500000  2.000000  0.000000  0.500000
# 5       10.714286  1.857143  0.857143  2.714286  0.571429  0.571429
# 6       10.727273  3.363636  0.363636  2.636364  0.545455  0.636364
# 7       13.531915  3.191489  0.446809  1.914894  0.787234  0.659574
# 8       12.453488  3.337209  0.337209  2.186047  0.697674  0.686047
# 9       12.548571  3.514286  0.434286  2.051429  0.834286  0.651429
# 10      12.315789  3.485380  0.441520  2.020468  0.716374  0.646199
# 11      11.586207  3.440613  0.390805  1.952107  0.657088  0.599617
# 12      11.666667  3.438339  0.395604  1.930403  0.724054  0.630037
# 13      12.079767  3.512646  0.402724  1.993191  0.723735  0.630350
# 14      11.567752  3.538229  0.390613  2.048448  0.694928  0.610901
# 15      11.938198  3.507818  0.371556  1.992554  0.709605  0.618764
# 16      12.033912  3.516562  0.406940  1.977918  0.656940  0.624606
# 17      11.745000  3.506000  0.421000  2.052000  0.699000  0.594000
# 18      11.463930  3.594527  0.409204  2.037313  0.699005  0.623134
# 19      12.251838  3.441176  0.415441  2.047794  0.737132  0.619485
# 20      12.985465  3.543605  0.398256  1.985465  0.651163  0.587209
# 21      11.772487  3.338624  0.465608  1.968254  0.746032  0.634921
# 22      11.853333  3.706667  0.346667  2.146667  0.693333  0.706667
# 23      11.146341  3.780488  0.390244  2.292683  0.682927  0.707317
#
#              완료코스      월간학습일     중단학습수   최종로그인(일)     커뮤참여도      학습성취도  \
# 평균접속시간
# 2        7.000000  21.000000  4.000000   7.000000  5.000000  76.000000
# 3       10.000000  15.000000  3.500000  18.000000  3.500000  81.500000
# 4       11.500000  14.500000  5.000000  18.000000  3.500000  78.000000
# 5       15.285714  12.000000  2.428571  11.285714  4.285714  71.428571
# 6       11.272727  14.545455  3.272727  10.818182  4.181818  74.909091
# 7       12.425532  11.872340  2.914894  14.978723  3.872340  73.361702
# 8       12.209302  13.011628  3.267442  15.918605  3.906977  75.965116
# 9       12.554286  13.331429  2.977143  15.348571  3.988571  76.142857
# 10      12.538012  12.801170  2.906433  15.508772  3.874269  74.862573
# 11      12.649425  12.377395  2.944444  14.950192  3.816092  74.701149
# 12      12.105006  12.368742  3.083028  14.719170  3.844933  74.908425
# 13      12.154669  12.550584  3.032101  14.776265  3.914397  74.791829
# 14      12.159727  12.608630  3.051476  15.236185  3.891749  75.155942
# 15      12.182427  12.293373  3.004468  15.159345  3.833209  75.110946
# 16      12.273659  12.513407  3.024448  15.209779  3.910095  75.647476
# 17      12.246000  12.347000  3.020000  14.891000  3.942000  74.907000
# 18      11.970149  12.788557  3.194030  14.674129  3.907960  74.752488
# 19      12.343750  12.906250  3.064338  14.843750  3.875000  74.369485
# 20      11.994186  12.933140  3.055233  15.020349  3.834302  75.005814
# 21      12.682540  11.783069  3.121693  15.619048  3.989418  76.291005
# 22      12.213333  13.720000  3.200000  14.973333  3.693333  72.706667
# 23      11.853659  12.926829  3.243902  13.487805  3.804878  73.365854
#
#         학습평균시간(분)
# 평균접속시간
# 2        1.000000
# 3        9.000000
# 4       11.500000
# 5       62.428571
# 6       68.454545
# 7       59.085106
# 8       61.139535
# 9       51.342857
# 10      51.926901
# 11      56.513410
# 12      56.736264
# 13      55.846304
# 14      54.960636
# 15      54.844378
# 16      56.026025
# 17      52.922000
# 18      55.090796
# 19      51.079044
# 20      53.563953
# 21      57.216931
# 22      56.413333
# 23      50.609756

# %%
sns.heatmap(df1_pivot, annot = True, cmap = 'Reds')
# Out:
# <Axes: ylabel='평균접속시간'>
